# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('data/cats_vs_dogs.csv', header=None)
feature_names = df1.iloc[0]
df1 = df1[1:]
feature_names = feature_names[1:6]
feature_names
# Out:
# 1       fetch
# 2      grumpy
# 3       bacon
# 4    cat_food
# 5    dog_food
# Name: 0, dtype: object

# %%
exp_var = set(df1.columns.values)
resp = df1[len(df1.columns.values)-1]

# %%
exp_var.remove(len(df1.columns.values)-1)
exp_var.remove(0)

# %%
y = [1 if e == '1' else -1 for e in resp]

# %%
X = df1[list(exp_var)]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
class_names = np.array(['dog', 'cat'], dtype='<U10')
feature_names = list(feature_names)
class_names
# Out:
# array(['dog', 'cat'], dtype='<U10')

# %%
from sklearn.datasets import load_iris
iris = load_iris()
cls = iris.target_names
cls
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
clf = clf.fit(X, y)
import graphviz
dot_data = export_graphviz(clf, out_file=None,
                           feature_names=feature_names,
                           class_names=class_names,
                           filled=True, rounded=True,
                           special_characters=True)
graph = graphviz.Source(dot_data)
graph.render("Cats and Dogs")
graph
